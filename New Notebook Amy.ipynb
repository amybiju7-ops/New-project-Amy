# %%
#UDISE TABLE 2023-2024

# %%
import pandas as pd

# %%
df = pd.read_csv('UDISE_2023-24_Table_2.1.csv')

# %%
df.head()
# Out:
#    Sl. No.               India/State/UT  Total Number of - Schools  \
# 0        1                        India                    1471891
# 1        2  Andaman and Nicobar Islands                        412
# 2        3               Andhra Pradesh                      61373
# 3        4            Arunachal Pradesh                       3490
# 4        5                        Assam                      56630
#
#    Total Number of - Enrolments  Total Number of - Teachers  \
# 0                     248045828                     9807600
# 1                         72119                        5750
# 2                       8741885                      338293
# 3                        323717                       24700
# 4                       6922533                      342199
#
#    Percentage Share of Schools by Category - Primary  \
# 0                                               50.0
# 1                                               50.7
# ...

# %%
df.tail(10)
# Out:
#     Sl. No. India/State/UT  Total Number of - Schools  \
# 27       28     Puducherry                        735
# 28       29         Punjab                      27404
# 29       30      Rajasthan                     107757
# 30       31         Sikkim                       1254
# 31       32     Tamil Nadu                      58722
# 32       33      Telangana                      42901
# 33       34        Tripura                       4923
# 34       35  Uttar Pradesh                     255087
# 35       36    Uttarakhand                      22551
# 36       37    West Bengal                      93945
#
#     Total Number of - Enrolments  Total Number of - Teachers  \
# 27                        244828                       13202
# 28                       5988681                      273092
# 29                      16786065                      775745
# 30                        121395                       15489
# ...

# %%
df.shape
# Out:
# (37, 17)

# %%
df.columns
# Out:
# Index(['Sl. No.', 'India/State/UT', 'Total Number of - Schools',
#        'Total Number of - Enrolments', 'Total Number of - Teachers',
#        'Percentage Share of Schools by Category - Primary',
#        'Percentage Share of Schools by Category - Upper Primary',
#        'Percentage Share of Schools by Category - Secondary',
#        'Percentage Share of Schools by Category - Higher Secondary',
#        'Percentage Share of Enrolments by level -  Primary ',
#        'Percentage Share of Enrolments by level -  Upper Primary ',
#        'Percentage Share of Enrolments by level - Secondary',
#        'Percentage Share of Enrolments by level - Higher Secondary',
#        'Percentage Share of Teachers by School Category - Primary',
#        'Percentage Share of Teachers by School Category - Upper Primary',
#        'Percentage Share of Teachers by School Category - Secondary',
#        'Percentage Share of Teachers by School Category - Higher Secondary'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 17 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Sl. No.                                                             37 non-null     int64
#  1   India/State/UT                                                      37 non-null     str
#  2   Total Number of - Schools                                           37 non-null     int64
#  3   Total Number of - Enrolments                                        37 non-null     int64
#  4   Total Number of - Teachers                                          37 non-null     int64
#  5   Percentage Share of Schools by Category - Primary                   37 non-null     float64
#  6   Percentage Share of Schools by Category - Upper Primary             37 non-null     float64
# ...

# %%
df.sort_values(by=['Percentage Share of Schools by Category - Secondary', 'Percentage Share of Teachers by School Category - Upper Primary'], ascending=False).head(5)
# Out:
#     Sl. No. India/State/UT  Total Number of - Schools  \
# 6         7     Chandigarh                        230
# 10       11            Goa                       1487
# 32       33      Telangana                      42901
# 27       28     Puducherry                        735
# 16       17      Karnataka                      75869
#
#     Total Number of - Enrolments  Total Number of - Teachers  \
# 6                         265706                       10237
# 10                        304735                       14594
# 32                       7293644                      341460
# 27                        244828                       13202
# 16                      11926303                      433942
#
#     Percentage Share of Schools by Category - Primary  \
# 6                                                 6.1
# 10                                               58.0
# 32                                               47.9
# ...

# %%
df.describe()
# Out:
#          Sl. No.  Total Number of - Schools  Total Number of - Enrolments  \
# count  37.000000               3.700000e+01                  3.700000e+01
# mean   19.000000               7.956168e+04                  1.340788e+07
# std    10.824355               2.407658e+05                  4.057760e+07
# min     1.000000               3.700000e+01                  1.259100e+04
# 25%    10.000000               3.490000e+03                  3.237170e+05
# 50%    19.000000               2.351700e+04                  5.599742e+06
# 75%    28.000000               6.137300e+04                  1.149671e+07
# max    37.000000               1.471891e+06                  2.480458e+08
#
#        Total Number of - Teachers  \
# count                3.700000e+01
# mean                 5.301405e+05
# std                  1.598759e+06
# min                  9.110000e+02
# 25%                  2.470000e+04
# 50%                  2.065910e+05
# 75%                  3.940530e+05
# ...

# %%
df["Percentage Share of Enrolments by level -  Upper Primary "]
# Out:
# 0     25.4
# 1     23.6
# 2     25.7
# 3     24.0
# 4     25.1
# 5     26.4
# 6     23.9
# 7     25.3
# 8     25.1
# 9     25.9
# 10    23.7
# 11    27.6
# 12    26.6
# 13    23.4
# 14    21.5
# 15    26.5
# 16    26.5
# 17    23.7
# 18    20.5
# 19    22.1
# 20    25.9
# 21    25.9
# 22    21.7
# 23    20.6
# 24    22.2
# 25    21.3
# 26    27.6
# 27    23.5
# 28    21.9
# 29    24.7
# 30    21.3
# 31    24.6
# 32    25.2
# 33    25.2
# 34    25.4
# 35    24.2
# 36    24.5
# Name: Percentage Share of Enrolments by level -  Upper Primary , dtype: float64

# %%
df["Percentage Share of Enrolments by level - Higher Secondary"]
# Out:
# 0     10.9
# 1     14.4
# 2     11.6
# 3      8.9
# 4      7.2
# 5      7.7
# 6     15.8
# 7      9.7
# 8      8.4
# 9     13.5
# 10    12.8
# 11     8.9
# 12    11.8
# 13    13.1
# 14     9.2
# 15     9.1
# 16    10.2
# 17    14.2
# 18     7.5
# 19    13.1
# 20     9.0
# 21    13.0
# 22     9.8
# 23     5.1
# 24     8.3
# 25     9.2
# 26    11.7
# 27    14.3
# 28    12.2
# 29    11.2
# 30    13.0
# 31    13.8
# 32    11.8
# 33    11.8
# 34    11.5
# 35    13.1
# 36    11.5
# Name: Percentage Share of Enrolments by level - Higher Secondary, dtype: float64

# %%
df.sort_values(
    by="Percentage Share of Schools by Category - Primary",
    ascending=False
)[["India/State/UT", "Percentage Share of Schools by Category - Primary"]].head(10)
# Out:
#       India/State/UT  Percentage Share of Schools by Category - Primary
# 36       West Bengal                                               79.3
# 4              Assam                                               66.2
# 23         Meghalaya                                               62.7
# 2     Andhra Pradesh                                               61.5
# 13  Himachal Pradesh                                               60.8
# 10               Goa                                               58.0
# 31        Tamil Nadu                                               57.9
# 7       Chhattisgarh                                               57.3
# 35       Uttarakhand                                               57.3
# 30            Sikkim                                               53.3

# %%
df[df["Percentage Share of Schools by Category - Primary"] > 50][[
    "India/State/UT",
    "Percentage Share of Schools by Category - Primary"
]]
# Out:
#                  India/State/UT  \
# 1   Andaman and Nicobar Islands
# 2                Andhra Pradesh
# 4                         Assam
# 7                  Chhattisgarh
# 10                          Goa
# 13             Himachal Pradesh
# 15                    Jharkhand
# 22                      Manipur
# 23                    Meghalaya
# 30                       Sikkim
# 31                   Tamil Nadu
# 33                      Tripura
# 34                Uttar Pradesh
# 35                  Uttarakhand
# 36                  West Bengal
#
#     Percentage Share of Schools by Category - Primary
# 1                                                50.7
# 2                                                61.5
# 4                                                66.2
# 7                                                57.3
# 10                                               58.0
# 13                                               60.8
# 15                                               52.5
# ...

# %%
df["Percentage Share of Schools by Category - Upper Primary"].mean()
# Out:
# np.float64(26.529729729729727)

# %%
df["Percentage Share of Schools by Category - Upper Primary"].mean().round(2)
# Out:
# np.float64(26.53)

# %%
df["Percentage Share of Schools by Category - Upper Primary"].median()
# Out:
# np.float64(25.3)

# %%
df["Percentage Share of Schools by Category - Secondary"].min()
# Out:
# np.float64(0.0)

# %%
df["Percentage Share of Schools by Category - Secondary"].max()
# Out:
# np.float64(30.4)

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# Sl. No.                                                               0
# India/State/UT                                                        0
# Total Number of - Schools                                             0
# Total Number of - Enrolments                                          0
# Total Number of - Teachers                                            0
# Percentage Share of Schools by Category - Primary                     0
# Percentage Share of Schools by Category - Upper Primary               0
# Percentage Share of Schools by Category - Secondary                   0
# Percentage Share of Schools by Category - Higher Secondary            0
# Percentage Share of Enrolments by level -  Primary                    0
# Percentage Share of Enrolments by level -  Upper Primary              0
# Percentage Share of Enrolments by level - Secondary                   0
# Percentage Share of Enrolments by level - Higher Secondary            0
# ...

# %%
df[[
    "India/State/UT",
    "Total Number of - Schools",
    "Percentage Share of Schools by Category - Primary"
]].sort_values(
    "Total Number of - Schools",
    ascending=False
).head(10)
# Out:
#     India/State/UT  Total Number of - Schools  \
# 0            India                    1471891
# 34   Uttar Pradesh                     255087
# 20  Madhya Pradesh                     123412
# 21     Maharashtra                     108237
# 29       Rajasthan                     107757
# 5            Bihar                      94686
# 36     West Bengal                      93945
# 16       Karnataka                      75869
# 26          Odisha                      61693
# 2   Andhra Pradesh                      61373
#
#     Percentage Share of Schools by Category - Primary
# 0                                                50.0
# 34                                               52.3
# 20                                               49.4
# 21                                               46.1
# 29                                               35.0
# 5                                                44.0
# 36                                               79.3
# ...
